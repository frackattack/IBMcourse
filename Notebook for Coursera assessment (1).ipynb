# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Stephanie Frackowiak** <br>
# Director

# %% [markdown]
# *I am interested in data science because I love figuring out why things are the way they are. Making observations, collecting data, and extrapolating insights is the best way to understand the world*

# %% [markdown]
# ### the code in cell 5 is going to add together the year of my birth and my age

# %%
n1 = 1975
n2 = 48
sum = n1+n2
print(format(sum))
# Out:
# 2023

# %% [markdown]
# <li> this is first line
#     <li> this is 2nd
#         <li> Number 3. is it driving you crazy I'm mixing up my number formats?</li>
#         Here is a picture for LOLZ:
#         <img src="https://media.istockphoto.com/id/158894647/photo/funny-dachshund.jpg?s=612x612&w=0&k=20&c=qsI_AfDe6Ecw-5aYt5DwNQye0QHDhzQ-DE78jodyUYc=" />
#         <hr>
#         <a href="https://www.lifehack.org/articles/lifestyle/53-fun-things-you-can-this-weekend.html">this is a link to something fun</a>
